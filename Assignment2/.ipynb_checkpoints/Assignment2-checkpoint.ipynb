# %% [markdown]
# # ENSF 519.01 Applied Data Science
# **Assignment 2** - 100 marks
#
# **Due:** October 18th, 04.00 pm.
#
#
# **IMPORTANT NOTE: each task must be implemented as asked, even if there are other easier or better solutions.**
#
# **How to deliver:**
# Edit this file and write your solutions in sections specified with `# Your solution`. Test your code and when you are done, submit this notebook as an `.ipynb` file to D2L dropbox.

# %% [markdown]
# ## Problem 1 - Most popular movies (55 points)
# In this assigment we want to do some basic data analysis on the most popular movies on IMDb right now. We do this in steps: first we take the list of most popular movies then we gather more informaion on each movie from the movie's page. These info are stored in pandas dataframes. Next we need to combine the information from these two tables, using pandas `merge` method. The resulting merged table might give us some insight on why some movies get more popular. Let's try and see what we can get!
#
# Complete the `get_page_html` function below so that it gets the HTML content of any given url. We get the HTML content and store it in a variable just once, because:
# 1. Downloading the web page content takes ~1-2 seconds. While you're writing the html parser code you need to run and test your code many many times. If you download the whole page everytime you want to test the parser, these download times add up to significantly slow you down.
# 2. Making a lot of requests to the same page of a website in a short period of time might make the firewall suspicious of an attack and block your IP address

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
import sys

page_url = 'https://www.imdb.com/chart/top'

def get_page_html(url):
    # Your solution
    response = requests.get(url, allow_redirects=True)
    if 200 <= response.status_code <= 299:
        return response.content
    else:
        raise Exception(f'status code: {response.status_code} outside of 2xx range')
    
    
    
top_movies_html = get_page_html(page_url)

# %% [markdown]
# Parse the HTML content above using Beautiful Soup to extract these data:
#
# * Rank (`rank`: int) **set this column as the index**
# * Name of the movie (`name`: str)
# * Its release year (`release_year`: int)
# * Rating (`rating`: float)
# * link to its detail page (`detail_url`: str)
#
# Store these in a pandas dataframe. The suggested column names and data types are specified in the parentheses above (20 points).

# %%
def get_top_movies(top_movies_page_html):    
    parser = BeautifulSoup(top_movies_page_html, 'html.parser')
    # Your solution.
    # Create more functions to make your code cleaner and more organazied as necessary.
    topMovies = []
    for movie_tr in parser.table.tbody.find_all('tr'):
        topMovies.append({
            "rank": int(movie_tr.find("td", {"class": "posterColumn"}).find("span", {"name": "rk"})['data-value']),
            "name": movie_tr.find("td", {"class": "titleColumn"}).a.text,
            "release_year": (movie_tr.find("td", {"class": "titleColumn"}).find("span", {"class": "secondaryInfo"}).text.rstrip(')').lstrip('(')),
            "rating": float(movie_tr.find("td", {"class": "ratingColumn imdbRating"}).strong.text),
            "detail_url": movie_tr.find("td", {"class": "titleColumn"}).a['href']
        })
    return pd.DataFrame(topMovies).set_index('rank') # A dataframe with the 4 columns mentioned above

top_movies = get_top_movies(top_movies_html)
top_movies  # Rank must be the index, the rows should match the webpage
# Out:
#                           name release_year  rating         detail_url
# rank
# 1     The Shawshank Redemption         1994     9.2  /title/tt0111161/
# 2                The Godfather         1972     9.1  /title/tt0068646/
# 3       The Godfather: Part II         1974     9.0  /title/tt0071562/
# 4              The Dark Knight         2008     9.0  /title/tt0468569/
# 5                 12 Angry Men         1957     8.9  /title/tt0050083/
# ...                        ...          ...     ...                ...
# 246    Guardians of the Galaxy         2014     8.0  /title/tt2015381/
# 247               Mou gaan dou         2002     8.0  /title/tt0338564/
# 248                    Aladdin         1992     8.0  /title/tt0103639/
# 249     La battaglia di Algeri         1966     8.0  /title/tt0058946/
# 250                    Solaris         1972     8.0  /title/tt0069293/
#
# [250 rows x 4 columns]

# %% [markdown]
# Now we proceed to step 2, we want to create a function that parses each individual movie's page. Just like the previous assignment on regular expressions, we try to get that working on one sample and only after we made sure that everything works properly we use a loop to get all the data that we need.

# %%
avengers_url = 'https://www.imdb.com/title/tt4154796/'
avengers_html = get_page_html(avengers_url)

# %% [markdown]
# Make a function that parses the html content of a movie details page and extracts these information:
#
# * Movie length in minutes (int)
# * Release date (convert the string to a python date object - use [`strptime` built-in function](https://www.programiz.com/python-programming/datetime/strptime) or regular expressions as you wish)
# * List of genres (list of strings)
# * Budget (int), if unavailable: ignore.
# * Name of the directors (list)
#
# Return these as a dictionary. You can extract more data as you wish. (20 points)

# %%
import re
from datetime import datetime 

def extract_movie_details(html):
    parser = BeautifulSoup(html, 'html.parser')
    # Your solution
    length_res = re.match("(\d+)h (\d+)min", 
        parser.find("div", {"class": "title_bar_wrapper"}).find("div", {"class": "subtext"}).time.text.strip())
    if length_res:
        hours, mins = length_res.groups()
        length = int(hours)*60 + int(mins)
    else:
        length = None
    
    budget_regx = re.compile(r"\bBudget:[\$A-Z]+(\d+(,\d+)+)")
    budget_res = budget_regx.search(parser.find("div", {"id": "titleDetails"}).text.strip())
    budget = None if budget_res is None else int(budget_res.groups()[0].replace(",", ""))
    
    release_date_res = re.match("^(\d+ \w+ \d+).*$", parser.find("div", {"class": "title_bar_wrapper"}).find("div", {"class": "subtext"}).find("a", {"title": "See more release dates"}).text.strip())
    release_date = None if release_date_res is None else datetime.strptime(release_date_res.groups()[0], "%d %B %Y")
    
    return {
        "length": length,
        "genres": list(map(lambda x: x.text , parser.find("div", {"class": "title_bar_wrapper"}).find("div", {"class": "subtext"}).find_all("a", {"title": None}))),
        "release_date": release_date,
        "budget": budget,
        "directors": list(map(lambda x: x.text, parser.find("div", {"class": "plot_summary"}).find("div", {"class": "credit_summary_item"}).find_all("a")))
    }
    
    
avengers_data = extract_movie_details(avengers_html)
print(avengers_data) 
# Expected: {
#     'length': 181, 
#     'genres': ['action', 'adventure', 'sci-fi'], 
#     'release_date': datetime.datetime(2019, 4, 26, 0, 0),
#     'budget': 356000000,
#     'directors': ['Anthony Russo', 'Joe Russo']
# }
# Out:
# {'length': 181, 'genres': ['Action', 'Adventure', 'Sci-Fi'], 'release_date': datetime.datetime(2019, 4, 26, 0, 0), 'budget': 356000000, 'directors': ['Anthony Russo', 'Joe Russo']}

# %% [markdown]
# Now get the list of detail page urls for all the movies:

# %%
urls = top_movies.set_index('name')['detail_url']
urls
# Out:
# name
# The Shawshank Redemption    /title/tt0111161/
# The Godfather               /title/tt0068646/
# The Godfather: Part II      /title/tt0071562/
# The Dark Knight             /title/tt0468569/
# 12 Angry Men                /title/tt0050083/
#                                   ...
# Guardians of the Galaxy     /title/tt2015381/
# Mou gaan dou                /title/tt0338564/
# Aladdin                     /title/tt0103639/
# La battaglia di Algeri      /title/tt0058946/
# Solaris                     /title/tt0069293/
# Name: detail_url, Length: 250, dtype: object

# %% [markdown]
# and loop through the movie name and urls created above (`urls`), use `extract_movie_details` and create a data frame out of the dictionaries. The dataframe should have a column storing the movie name and one column for each item in the dictionary (length, genres, ...). If any piece of data was not availble for a movie (e.g. budget might not be available for some) just leave it, pandas will use `NaN` for that cell. (10 points)

# %%
# Your solution
from urllib.parse import urljoin
movies_detail = pd.DataFrame([{"name": name, **extract_movie_details(get_page_html(urljoin(page_url, url))) }for name, url in urls.iteritems()])
movies_detail
# Out:
#                          name  length                          genres  \
# 0    The Shawshank Redemption   142.0                         [Drama]
# 1               The Godfather   175.0                  [Crime, Drama]
# 2      The Godfather: Part II   202.0                  [Crime, Drama]
# 3             The Dark Knight   152.0          [Action, Crime, Drama]
# 4                12 Angry Men    96.0                         [Drama]
# ..                        ...     ...                             ...
# 245   Guardians of the Galaxy   121.0     [Action, Adventure, Comedy]
# 246              Mou gaan dou   101.0         [Crime, Drama, Mystery]
# 247                   Aladdin    90.0  [Animation, Adventure, Comedy]
# 248    La battaglia di Algeri   121.0                    [Drama, War]
# 249                   Solaris   167.0        [Drama, Mystery, Sci-Fi]
#
#     release_date       budget                    directors
# 0     1994-10-14   25000000.0             [Frank Darabont]
# 1     1972-03-24    6000000.0       [Francis Ford Coppola]
# 2     1974-12-20   13000000.0       [Francis Ford Coppola]
# 3     2008-07-18  185000000.0          [Christopher Nolan]
# 4     1957-04-10     350000.0               [Sidney Lumet]
# ..           ...          ...                          ...
# 245   2014-08-01  170000000.0                 [James Gunn]
# 246   2002-12-12    6428966.0       [Andrew Lau, Alan Mak]
# 247   1992-12-25   28000000.0  [Ron Clements, John Musker]
# 248   1967-02-25     800000.0           [Gillo Pontecorvo]
# 249   1972-09-26    1000000.0           [Andrei Tarkovsky]
#
# [250 rows x 6 columns]

# %% [markdown]
# Use pandas' `merge` method to join these two tables into one. Merge on movie name. (5 points)

# %%
merged = pd.merge(
    top_movies, movies_detail,
    left_on="name", right_on="name"
)
merged
# Out:
#                          name release_year  rating         detail_url  length  \
# 0    The Shawshank Redemption         1994     9.2  /title/tt0111161/   142.0
# 1               The Godfather         1972     9.1  /title/tt0068646/   175.0
# 2      The Godfather: Part II         1974     9.0  /title/tt0071562/   202.0
# 3             The Dark Knight         2008     9.0  /title/tt0468569/   152.0
# 4                12 Angry Men         1957     8.9  /title/tt0050083/    96.0
# ..                        ...          ...     ...                ...     ...
# 247   Guardians of the Galaxy         2014     8.0  /title/tt2015381/   121.0
# 248              Mou gaan dou         2002     8.0  /title/tt0338564/   101.0
# 249                   Aladdin         1992     8.0  /title/tt0103639/    90.0
# 250    La battaglia di Algeri         1966     8.0  /title/tt0058946/   121.0
# 251                   Solaris         1972     8.0  /title/tt0069293/   167.0
#
#                              genres release_date       budget  \
# 0                           [Drama]   1994-10-14   25000000.0
# 1                    [Crime, Drama]   1972-03-24    6000000.0
# 2                    [Crime, Drama]   1974-12-20   13000000.0
# 3            [Action, Crime, Drama]   2008-07-18  185000000.0
# 4                           [Drama]   1957-04-10     350000.0
# ..                              ...          ...          ...
# 247     [Action, Adventure, Comedy]   2014-08-01  170000000.0
# 248         [Crime, Drama, Mystery]   2002-12-12    6428966.0
# 249  [Animation, Adventure, Comedy]   1992-12-25   28000000.0
# 250                    [Drama, War]   1967-02-25     800000.0
# 251        [Drama, Mystery, Sci-Fi]   1972-09-26    1000000.0
#
#                        directors
# 0               [Frank Darabont]
# 1         [Francis Ford Coppola]
# 2         [Francis Ford Coppola]
# 3            [Christopher Nolan]
# 4                 [Sidney Lumet]
# ..                           ...
# 247                 [James Gunn]
# 248       [Andrew Lau, Alan Mak]
# 249  [Ron Clements, John Musker]
# 250           [Gillo Pontecorvo]
# 251           [Andrei Tarkovsky]
#
# [252 rows x 9 columns]

# %% [markdown]
# # Problem 2 - Visualizing and Analysing (45 points)
#
# Now, we have a data frame containing information about the most popular IMDb movies as of now. In this part we are going to use matplotlib to visualize those data and see if we can find any meaningful features that can predict success of a movie.
#
# This problem uses the results of the problem 1. If you can't do Problem 1 for any reason, we have a csv file uploaded on D2L that contains the final result of Problem 1. You can download that file and use `pd.read_csv` to create a dataframe from it. Please note that you need to convert the release date from an string to a datetime object. Also you need to parse the `genres` and `directors` columns into python lists.
#
# ## Releasing Season and Year
# First, create a column that contains which season the movie was released in, if data isn't available ignore that row. Then use pandas aggregation methods to count the movies released in each season of the year. Plot a [bar chart](https://matplotlib.org/3.1.1/gallery/lines_bars_and_markers/barchart.html#sphx-glr-gallery-lines-bars-and-markers-barchart-py) that shows the average rating of movies made in each season per year for the last **20 years**. Show the 4 seasons of each year next to each other. Use the ticks on X axis to show the year and the colours of the bars to show the season. Also, put a legend on the chart. (10 points)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from dateutil.relativedelta import relativedelta
import datetime

years_ago_20 = datetime.datetime.now() - relativedelta(years=20)

df = merged.loc[merged['release_date']>years_ago_20,:].copy()
df = df.dropna()
# Your solution
numToMonth = {1: "Winter", 2: "Spring", 3: "Summer", 4: "Autumn"}
df['seasons'] = df['release_date'].apply(lambda row: numToMonth[(row.month%12+3)//3])

season_info = df.groupby(['release_year', 'seasons']).agg(average=('rating', 'mean'), count=('name', 'count'))
# season_info.reset_index(level=1, inplace=True)
fig, ax = plt.subplots(figsize=(15,7))
season_info['average'].unstack(level=1).plot(kind='bar', ax=ax)

# %% [markdown]
# ## Genre and Directors
#
# Create two pie charts in a figure next to each other. In one, plot the number of movies in each genre and in the other, plot the number of movies directed by each director. Since there are many directors only keep the people who have directed 3 movies or more. First create two dataframes for the charts. One should have two columns:
# * genre (set as **index**)
# * count_ratings
# * mean_ratings (**sort the dataframe** by this column in decending order)
#
# and the other one:
# * name (set as **index**)
# * count_movies (**sort the dataframe** by this column in decending order)
#
# After making the dataframes you can proceed to drawing the two [pie charts](https://matplotlib.org/3.1.1/gallery/pie_and_polar_charts/pie_features.html#sphx-glr-gallery-pie-and-polar-charts-pie-features-py) based on them. Sorting the table before drawing the charts make the slices sorted, try drawing charts for the same data but comment out the line of code you wrote for sorting and see the difference. Make an appropriate title for each chart, also show the name of each genre/each director next to each pie slice. (20 points)

# %%
df = merged.copy()

lens_genres = [len(item) for item in df['genres']]
genre_stats = pd.DataFrame({"genres": np.hstack(df['genres']), 'ratings': np.repeat(df['rating'].values, lens_genres)}).groupby("genres").agg(count_ratings=('ratings', 'count'), mean_ratings=('ratings', 'mean')).sort_values(by ='mean_ratings', ascending=False)
genre_stats
# Out:
#            count_ratings  mean_ratings
# genres
# Western                6      8.366667
# Horror                 4      8.350000
# Fantasy               19      8.342105
# Music                  4      8.325000
# Action                36      8.288889
# Family                13      8.284615
# Adventure             56      8.276786
# Sci-Fi                25      8.272000
# Crime                 56      8.271429
# War                   16      8.256250
# Drama                182      8.255495
# Mystery               28      8.232143
# Animation             21      8.223810
# Thriller              39      8.223077
# History               14      8.221429
# Biography             25      8.216000
# Romance               22      8.213636
# Film-Noir              5      8.200000
# Comedy                44      8.188636
# Sport                  5      8.100000
# Musical                3      8.066667

# %%
lens_directors = [len(item) for item in df['directors']]

director_stats = pd.DataFrame({"directors": np.hstack(df['directors']), 'ratings': np.repeat(df['rating'].values, lens_directors)}).groupby("directors").agg(count_movies=('ratings', 'count'), mean_ratings=('ratings', 'mean')).sort_values(by ='count_movies', ascending=False)
director_stats = director_stats[director_stats['count_movies']>2]
director_stats
# Out:
#                       count_movies  mean_ratings
# directors
# Christopher Nolan                7      8.514286
# Stanley Kubrick                  7      8.314286
# Martin Scorsese                  7      8.271429
# Steven Spielberg                 6      8.366667
# Alfred Hitchcock                 6      8.266667
# Billy Wilder                     6      8.216667
# Charles Chaplin                  5      8.340000
# Quentin Tarantino                5      8.400000
# Akira Kurosawa                   5      8.280000
# Hayao Miyazaki                   5      8.260000
# Francis Ford Coppola             4      8.725000
# Sergio Leone                     4      8.450000
# James Cameron                    3      8.266667
# Joel Coen                        3      8.100000
# Lee Unkrich                      3      8.200000
# Clint Eastwood                   3      8.133333
# Ethan Coen                       3      8.100000
# David Fincher                    3      8.500000
# Frank Capra                      3      8.233333
# Ingmar Bergman                   3      8.100000
# 1 more credit                    3      8.166667
# Peter Jackson                    3      8.800000
# Rajkumar Hirani                  3      8.100000
# Andrei Tarkovsky                 3      8.066667
# Ridley Scott                     3      8.333333
# Pete Docter                      3      8.100000

# %%
fig, (counts_axis, directors_axis) = plt.subplots(1, 2, figsize=(20, 10))
# Your solution
genre_stats.plot.pie(ax=counts_axis, y='count_ratings')
director_stats.plot.pie(ax=directors_axis, y='count_movies')

# %% [markdown]
# ## Budget
#
# Make a scatter plot with movies length and budget as the x and y axes. Since the budgets are not adjusted for inflation, to approximate that, color code the data points so that the movies that are released in the same decade have the same color. Use `alpha` parameter to make the points 50% transparent so that overlapping points are better visible. Set the proper axis labels and chart title. Also add a `colorbar` to show which color is associated with which decade. (15 points)

# %%
df = merged.loc[:, ('name', 'release_year', 'budget', 'length')].copy()
# Your solution
df['decade'] = df['release_year'].apply(lambda x: int(x)-int(x)%10)
df.drop('release_year', axis=1, inplace=True)
df
# Out:
#                          name       budget  length  decade
# 0    The Shawshank Redemption   25000000.0   142.0    1990
# 1               The Godfather    6000000.0   175.0    1970
# 2      The Godfather: Part II   13000000.0   202.0    1970
# 3             The Dark Knight  185000000.0   152.0    2000
# 4                12 Angry Men     350000.0    96.0    1950
# ..                        ...          ...     ...     ...
# 247   Guardians of the Galaxy  170000000.0   121.0    2010
# 248              Mou gaan dou    6428966.0   101.0    2000
# 249                   Aladdin   28000000.0    90.0    1990
# 250    La battaglia di Algeri     800000.0   121.0    1960
# 251                   Solaris    1000000.0   167.0    1970
#
# [252 rows x 4 columns]

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 10))
plt.style.use('seaborn-whitegrid')

number_of_unique_decades = df.groupby('decade')['name'].count().shape[0]
color_map = plt.get_cmap('jet', number_of_unique_decades)
# Your solution
df.plot.scatter(ax=ax, x='length', y='budget', colormap=color_map, c='decade', alpha=0.5)
